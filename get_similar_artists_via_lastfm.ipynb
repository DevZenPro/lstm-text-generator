# %% [markdown]
# # Get similar artists via last.fm
# * Documentation top: https://www.last.fm/api/intro
# * artist.getSimilar: https://www.last.fm/api/show/artist.getSimilar

# %%
import requests

with open('lastfm_api_key.txt') as f:
    lastfm_api_key = f.read()

# %%
def ask_lastfm_similar_artists(artist):
    url = 'http://ws.audioscrobbler.com/2.0/'

    data = {'method': 'artist.getsimilar', 
            'artist': artist, 
            'autocorrect': 0,
            'api_key': lastfm_api_key, 
            'format': 'json'}
    
    response = requests.post(url, data=data)
    
    if response.status_code == 200:
        r = response.json()
        similar_list = r['similarartists']['artist']
        return similar_list
    
    print('Sorry, some kind of error with status code {}'.format(response.status_code))
    return None

# %%
def print_lastfm_response(similar_list):
    print('# of similar artists: {:,}'.format(len(similar_list)))
    for sim in similar_list:
        print(sim['match'], sim['name'])  # match is b/w 0 and 1 (float)

# %%
def parse_lastfm_response(similar_list):
    list_ = []
    for sim in similar_list:
        list_.append((sim['name'], float(sim['match'])))  # match is b/w 0 and 1 (float)
    return list_

# %%
def get_top_n_similar_artists(artist, n=5, match_min=0, include_src=False):
    similar_list = ask_lastfm_similar_artists(artist)    
    if similar_list is None:
        return

    list_ = parse_lastfm_response(similar_list)
    output = []
    for i, name_match in enumerate(list_):
        name, match = name_match
        if (i < n) and (match >= match_min):
            if include_src:
                output.append((artist, name))
            else:
                output.append(name)
    return output

# %%
get_top_n_similar_artists('jimi hendrix', n=10, match_min=0.5)
# Out:
# ['The Jimi Hendrix Experience', 'Cream', 'Led Zeppelin', 'The Doors']

# %%
def get_top_n_linked_artists(artist, n_min=50, match_min=0.5, n_per_artist=5, include_src=False):
    if include_src:
        output = [(artist, artist)]
    else:
        output = [artist]
        
    queue = [artist]
    while True:
        if len(queue) == 0:
            print('Couldn\'t find {:,} artists...'.format(n_min))
            break
        
        focus = queue[0]
        list_ = get_top_n_similar_artists(focus, n=n_per_artist, match_min=match_min, include_src=False)
        
        to_add = []
        for elem in list_:  # Check if it's already checked/added
            if include_src:
                if elem.lower() in [o.lower() for _, o in output]:
                    continue
                to_add.append((focus, elem))
            else:
                if elem.lower() in [o.lower() for o in output]:
                    continue
                to_add.append(elem)
        
        output.extend(to_add)
        if len(output) >= n_min:
            break
        
        if include_src:
            queue.extend([elem for _, elem in to_add])
        else:
            queue.extend(to_add)       
        queue = queue[1:]  # Remove current artist
            
    return output

# %%
get_top_n_linked_artists('david bowie', n_min=300, match_min=0, n_per_artist=10, include_src=True)
# Out:
# [('david bowie', 'david bowie'),
#  ('david bowie', 'Tin Machine'),
#  ('david bowie', 'Lou Reed'),
#  ('david bowie', 'Iggy Pop'),
#  ('david bowie', 'Roxy Music'),
#  ('david bowie', 'The Velvet Underground'),
#  ('david bowie', 'T. Rex'),
#  ('david bowie', 'Queen & David Bowie'),
#  ('david bowie', 'The Rolling Stones'),
#  ('david bowie', 'Queen'),
#  ('david bowie', 'Brian Eno'),
#  ('Tin Machine', 'The Cult'),
#  ('Tin Machine', 'Porno for Pyros'),
#  ('Tin Machine', 'Cheap Trick'),
#  ('Tin Machine', "Jane's Addiction"),
#  ('Tin Machine', 'Nick Cave & The Bad Seeds'),
#  ('Tin Machine', 'R.E.M.'),
#  ('Tin Machine', 'Therapy?'),
#  ('Tin Machine', 'Robert Plant'),
#  ('Tin Machine', 'Morrissey'),
#  ('Lou Reed', 'Lou Reed & John Cale'),
#  ('Lou Reed', 'John Cale'),
#  ('Lou Reed', 'Neil Young'),
#  ('Lou Reed', 'Patti Smith'),
#  ('Lou Reed', 'The Stooges'),
#  ('Lou Reed', 'Bob Dylan'),
#  ('Iggy Pop', 'Iggy Pop & James Williamson'),
#  ('Iggy Pop', 'The Clash'),
#  ('Iggy Pop', 'Ramones'),
#  ('Iggy Pop', 'Sex Pistols'),
#  ('Iggy Pop', 'New York Dolls'),
#  ('Roxy Music', 'Bryan Ferry'),
#  ('Roxy Music', 'Sparks'),
#  ('Roxy Music', 'Japan'),
#  ('Roxy Music', 'XTC'),
#  ('Roxy Music', 'Talking Heads'),
#  ('Roxy Music', 'Ultravox'),
#  ('The Velvet Underground', 'Nico'),
#  ('The Velvet Underground', 'Television'),
#  ('The Velvet Underground', 'Captain Beefheart & His Magic Band'),
#  ('The Velvet Underground', 'Love'),
#  ('The Velvet Underground', 'The Modern Lovers'),
#  ('The Velvet Underground', 'The Kinks'),
#  ('T. Rex', 'Marc Bolan'),
#  ('T. Rex', 'Mott the Hoople'),
#  ('T. Rex', 'Gary Glitter'),
#  ('T. Rex', 'Slade'),
#  ('T. Rex', 'Sweet'),
#  ('Queen & David Bowie', 'David Bowie & Mick Jagger'),
#  ('Queen & David Bowie', 'Freddie Mercury'),
#  ('Queen & David Bowie', 'George Michael and Queen'),
#  ('Queen & David Bowie', 'Freddie Mercury & Montserrat Caballé'),
#  ('Queen & David Bowie', 'Brian May'),
#  ('Queen & David Bowie', 'Queen + Paul Rodgers'),
#  ('Queen & David Bowie', 'Robert Palmer'),
#  ('Queen & David Bowie', 'Mike & The Mechanics'),
#  ('The Rolling Stones', 'The Who'),
#  ('The Rolling Stones', 'Keith Richards'),
#  ('The Rolling Stones', 'Mick Jagger'),
#  ('The Rolling Stones', 'Led Zeppelin'),
#  ('The Rolling Stones', 'John Lennon'),
#  ('The Rolling Stones', 'The Doors'),
#  ('The Rolling Stones', 'The Yardbirds'),
#  ('The Rolling Stones', 'Cream'),
#  ('Queen', 'Roger Taylor'),
#  ('Queen', 'Deep Purple'),
#  ('Queen', 'The Cross'),
#  ('Queen', 'Aerosmith'),
#  ('Brian Eno', 'Harold Budd/Brian Eno'),
#  ('Brian Eno', 'Fripp & Eno'),
#  ('Brian Eno', 'Cluster & Brian Eno'),
#  ('Brian Eno', 'Brian Eno & David Byrne'),
#  ('Brian Eno', 'Harold Budd'),
#  ('Brian Eno', 'Laraaji'),
#  ('Brian Eno', 'Brian Eno & John Cale'),
#  ('Brian Eno', 'Roger Eno'),
#  ('Brian Eno', 'Cluster'),
#  ('Brian Eno', 'Stars of the Lid'),
#  ('The Cult', 'The Mission'),
#  ('The Cult', 'The Southern Death Cult'),
#  ('The Cult', 'The Sisters of Mercy'),
#  ('The Cult', 'Fields of the Nephilim'),
#  ('The Cult', 'Def Leppard'),
#  ('The Cult', 'Whitesnake'),
#  ('The Cult', 'Tesla'),
#  ('The Cult', 'New Model Army'),
#  ('The Cult', 'Van Halen'),
#  ('The Cult', 'David Lee Roth'),
#  ('Porno for Pyros', 'Blind Melon'),
#  ('Porno for Pyros', 'Soul Coughing'),
#  ('Porno for Pyros', 'Perry Farrell'),
#  ('Porno for Pyros', 'Marcy Playground'),
#  ('Porno for Pyros', 'Sugar'),
#  ('Porno for Pyros', 'Sponge'),
#  ('Porno for Pyros', 'The Lemonheads'),
#  ('Porno for Pyros', 'Screaming Trees'),
#  ('Porno for Pyros', 'Stone Temple Pilots'),
#  ('Cheap Trick', 'Boston'),
#  ('Cheap Trick', 'REO Speedwagon'),
#  ('Cheap Trick', 'April Wine'),
#  ('Cheap Trick', 'The Cars'),
#  ('Cheap Trick', 'Heart'),
#  ('Cheap Trick', 'Ace Frehley'),
#  ('Cheap Trick', 'Sammy Hagar'),
#  ('Cheap Trick', 'Styx'),
#  ('Cheap Trick', 'Night Ranger'),
#  ("Jane's Addiction", 'Mother Love Bone'),
#  ("Jane's Addiction", 'Faith No More'),
#  ("Jane's Addiction", 'Dave Navarro'),
#  ("Jane's Addiction", 'The Smashing Pumpkins'),
#  ("Jane's Addiction", 'Soundgarden'),
#  ("Jane's Addiction", 'Mudhoney'),
#  ('Nick Cave & The Bad Seeds', 'Grinderman'),
#  ('Nick Cave & The Bad Seeds', 'The Birthday Party'),
#  ('Nick Cave & The Bad Seeds', 'Nick Cave'),
#  ('Nick Cave & The Bad Seeds', 'Tom Waits'),
#  ('Nick Cave & The Bad Seeds', 'PJ Harvey'),
#  ('Nick Cave & The Bad Seeds', 'Mick Harvey'),
#  ('Nick Cave & The Bad Seeds', 'Leonard Cohen'),
#  ('Nick Cave & The Bad Seeds', 'Rowland S. Howard'),
#  ('Nick Cave & The Bad Seeds', 'Mark Lanegan'),
#  ('Nick Cave & The Bad Seeds', 'The Boys Next Door'),
#  ('R.E.M.', 'U2'),
#  ('R.E.M.', 'Pixies'),
#  ('R.E.M.', 'Counting Crows'),
#  ('R.E.M.', '10,000 Maniacs'),
#  ('R.E.M.', 'Bruce Springsteen'),
#  ('R.E.M.', 'The Replacements'),
#  ('R.E.M.', 'Pearl Jam'),
#  ('R.E.M.', 'Toad The Wet Sprocket'),
#  ('Therapy?', 'The Wildhearts'),
#  ('Therapy?', 'Terrorvision'),
#  ('Therapy?', 'Life of Agony'),
#  ('Therapy?', 'dEUS'),
#  ('Therapy?', 'Afghan Whigs'),
#  ('Therapy?', 'The Almighty'),
#  ('Therapy?', 'Skunk Anansie'),
#  ('Therapy?', 'Manic Street Preachers'),
#  ('Therapy?', 'Ugly Kid Joe'),
#  ('Robert Plant', 'Page & Plant'),
#  ('Robert Plant', 'Jimmy Page'),
#  ('Robert Plant', 'Robert Plant And The Strange Sensation'),
#  ('Robert Plant', 'The Honeydrippers'),
#  ('Robert Plant', 'Coverdale/Page'),
#  ('Robert Plant', 'Tom Petty'),
#  ('Robert Plant', 'David Gilmour'),
#  ('Robert Plant', 'Black Country Communion'),
#  ('Morrissey', 'The Smiths'),
#  ('Morrissey', 'Johnny Marr'),
#  ('Morrissey', 'Suede'),
#  ('Morrissey', 'Pulp'),
#  ('Morrissey', 'New Order'),
#  ('Morrissey', 'Gene'),
#  ('Morrissey', 'The Libertines'),
#  ('Morrissey', 'The Stone Roses'),
#  ('Morrissey', 'Echo & the Bunnymen'),
#  ('Morrissey', 'The Cure'),
#  ('Lou Reed & John Cale', 'Liz Phair'),
#  ('Lou Reed & John Cale', 'Frank Black'),
#  ('Lou Reed & John Cale', 'Tim Buckley'),
#  ('Lou Reed & John Cale', 'David Byrne'),
#  ('Lou Reed & John Cale', 'Robert Wyatt'),
#  ('John Cale', 'Scott Walker'),
#  ('John Cale', 'Richard & Linda Thompson'),
#  ('Neil Young', 'Neil Young & Crazy Horse'),
#  ('Neil Young', 'Crosby, Stills, Nash & Young'),
#  ('Neil Young', 'Buffalo Springfield'),
#  ('Neil Young', 'The Band'),
#  ('Neil Young', 'Crosby, Stills & Nash'),
#  ('Neil Young', 'Stephen Stills'),
#  ('Neil Young', 'The Stills-Young Band'),
#  ('Neil Young', 'David Crosby'),
#  ('Patti Smith', 'Marianne Faithfull'),
#  ('Patti Smith', 'X-Ray Spex'),
#  ('The Stooges', 'MC5'),
#  ('The Stooges', 'Richard Hell and the Voidoids'),
#  ('The Stooges', 'The Sonics'),
#  ('The Stooges', 'Dead Boys'),
#  ('Bob Dylan', 'Bob Dylan and The Band'),
#  ('Bob Dylan', 'Van Morrison'),
#  ('Bob Dylan', 'Woody Guthrie'),
#  ('Bob Dylan', 'The Byrds'),
#  ('Bob Dylan', 'Joan Baez'),
#  ('Iggy Pop & James Williamson', 'Johnny Thunders'),
#  ('Iggy Pop & James Williamson', 'The Gun Club'),
#  ('The Clash', 'Joe Strummer and the Mescaleros'),
#  ('The Clash', 'Buzzcocks'),
#  ('The Clash', 'Stiff Little Fingers'),
#  ('The Clash', 'The Damned'),
#  ('The Clash', 'Joe Strummer'),
#  ('The Clash', 'The Jam'),
#  ('The Clash', 'Dead Kennedys'),
#  ('The Clash', 'The Undertones'),
#  ('Ramones', 'Joey Ramone'),
#  ('Ramones', 'Dee Dee Ramone'),
#  ('Ramones', 'Misfits'),
#  ('Ramones', 'Rancid'),
#  ('Ramones', 'Bad Religion'),
#  ('Ramones', 'The Adicts'),
#  ('Sex Pistols', 'Sid Vicious'),
#  ('Sex Pistols', 'The Exploited'),
#  ('Sex Pistols', 'UK Subs'),
#  ('Sex Pistols', 'GBH'),
#  ('New York Dolls', 'Johnny Thunders & The Heartbreakers'),
#  ('New York Dolls', 'The Dictators'),
#  ('New York Dolls', 'The Heartbreakers'),
#  ('New York Dolls', 'The Vibrators'),
#  ('Bryan Ferry', 'Bryan Ferry & Roxy Music'),
#  ('Bryan Ferry', 'ABC'),
#  ('Bryan Ferry', 'Simple Minds'),
#  ('Bryan Ferry', 'Duran Duran'),
#  ('Bryan Ferry', 'Eurythmics'),
#  ('Bryan Ferry', 'Heaven 17'),
#  ('Bryan Ferry', 'The Pretenders'),
#  ('Sparks', 'Adam and the Ants'),
#  ('Sparks', 'Klaus Nomi'),
#  ('Sparks', 'Adam Ant'),
#  ('Sparks', 'Devo'),
#  ('Sparks', 'Orchestral Manoeuvres in the Dark'),
#  ('Japan', 'Dalis Car'),
#  ('Japan', 'John Foxx'),
#  ('Japan', 'Visage'),
#  ('Japan', 'The Human League'),
#  ('Japan', 'The Associates'),
#  ('Japan', 'China Crisis'),
#  ('XTC', 'Andy Partridge'),
#  ('XTC', 'Squeeze'),
#  ('XTC', 'Elvis Costello & The Attractions'),
#  ('XTC', 'Elvis Costello'),
#  ('XTC', 'Prefab Sprout'),
#  ('XTC', 'The The'),
#  ('XTC', 'Magazine'),
#  ('XTC', 'The Teardrop Explodes'),
#  ('Talking Heads', 'Tom Tom Club'),
#  ('Talking Heads', 'Gang of Four'),
#  ('Talking Heads', 'Wire'),
#  ('Talking Heads', 'Joy Division'),
#  ('Ultravox', 'Midge Ure'),
#  ('Ultravox', 'A Flock of Seagulls'),
#  ('Ultravox', 'Blancmange'),
#  ('Ultravox', 'Spandau Ballet'),
#  ('Nico', 'Diamanda Galás'),
#  ('Nico', 'Vashti Bunyan'),
#  ('Nico', 'Karen Dalton'),
#  ('Nico', 'Joni Mitchell'),
#  ('Television', 'Tom Verlaine'),
#  ('Television', 'Pere Ubu'),
#  ('Captain Beefheart & His Magic Band', 'The Mothers of Invention'),
#  ('Captain Beefheart & His Magic Band', 'The Red Krayola'),
#  ('Captain Beefheart & His Magic Band', 'Frank Zappa'),
#  ('Captain Beefheart & His Magic Band', 'The Residents'),
#  ('Captain Beefheart & His Magic Band', 'The Pop Group'),
#  ('Captain Beefheart & His Magic Band', 'Faust'),
#  ('Captain Beefheart & His Magic Band', 'Henry Cow'),
#  ('Captain Beefheart & His Magic Band', 'Can'),
#  ('Captain Beefheart & His Magic Band', 'The United States of America'),
#  ('Love', '13th Floor Elevators'),
#  ('Love', 'The Beau Brummels'),
#  ('Love', 'Tomorrow'),
#  ('Love', 'The Pretty Things'),
#  ('Love', 'The Zombies'),
#  ('Love', 'Moby Grape'),
#  ('Love', 'Country Joe & The Fish'),
#  ('Love', 'Kaleidoscope'),
#  ('Love', 'The Electric Prunes'),
#  ('The Modern Lovers', 'Jonathan Richman And The Modern Lovers'),
#  ('The Modern Lovers', 'Jonathan Richman'),
#  ('The Modern Lovers', 'Big Star'),
#  ('The Modern Lovers', 'The Monks'),
#  ('The Modern Lovers', 'Parquet Courts'),
#  ('The Kinks', 'Small Faces'),
#  ('The Kinks', 'Dave Davies'),
#  ('The Kinks', 'The Beach Boys'),
#  ('The Kinks', 'The Move'),
#  ('Marc Bolan', 'Steve Harley'),
#  ('Marc Bolan', 'Suzi Quatro'),
#  ('Marc Bolan', 'MUD'),
#  ('Marc Bolan', 'Steve Harley & Cockney Rebel'),
#  ('Marc Bolan', 'Bay City Rollers'),
#  ('Mott the Hoople', 'Ian Hunter'),
#  ('Mott the Hoople', 'Mick Ronson'),
#  ('Mott the Hoople', 'Faces'),
#  ('Mott the Hoople', 'Badfinger'),
#  ('Mott the Hoople', 'Cockney Rebel'),
#  ('Mott the Hoople', 'The Sensational Alex Harvey Band'),
#  ('Gary Glitter', 'The Glitter Band'),
#  ('Gary Glitter', 'Alvin Stardust'),
#  ('Gary Glitter', 'David Essex'),
#  ('Gary Glitter', 'The Rubettes'),
#  ('Slade', 'Status Quo'),
#  ('Slade', 'Nazareth'),
#  ('Slade', 'Geordie'),
#  ('Slade', 'Uriah Heep'),
#  ('Slade', 'UFO'),
#  ('David Bowie & Mick Jagger', 'Prince & The Revolution'),
#  ('David Bowie & Mick Jagger', 'John Parr'),
#  ('David Bowie & Mick Jagger', 'Eric Carmen'),
#  ('David Bowie & Mick Jagger', 'Steve Winwood'),
#  ('Freddie Mercury', 'Larry Lurex'),
#  ('Freddie Mercury', 'Elton John'),
#  ('Freddie Mercury', 'Electric Light Orchestra')]
