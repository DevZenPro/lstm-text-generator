# %% [markdown]
# # Get wikipedia data via api
# * Overview: https://pypi.python.org/pypi/wikipedia/
# * Documentation: https://wikipedia.readthedocs.io/en/latest/code.html

# %%
import wikipedia

# %%
what = 'Lauryn Hill'

# %%
wikipedia.page(what).__dict__
# Out:
# {'original_title': 'Lauryn Hill',
#  'pageid': '162864',
#  'title': 'Lauryn Hill',
#  'url': 'https://en.wikipedia.org/wiki/Lauryn_Hill'}

# %%
print(wikipedia.page(what).summary)
# Out:
# Lauryn Noelle Hill (born May 26, 1975) is an American singer, songwriter, rapper, record producer, and actress. She is best known for being a member of the Fugees and for her critically acclaimed solo album The Miseducation of Lauryn Hill, which won numerous awards and broke several sales records.
# ...

# %%
print(wikipedia.page(what).content)
# Out:
# Lauryn Noelle Hill (born May 26, 1975) is an American singer, songwriter, rapper, record producer, and actress. She is best known for being a member of the Fugees and for her critically acclaimed solo album The Miseducation of Lauryn Hill, which won numerous awards and broke several sales records.
# ...

# %%
print(wikipedia.page(what).links)
# Out:
# ['1989 (Taylor Swift album)', '21 (Adele album)', '25 (Adele album)', '41st Annual Grammy Awards', '41st Grammy Awards', '500 Greatest Albums of All Time', '50 Most Beautiful People', '52nd Street (album)', 'ABC Afterschool Specials', 'A Man and His Music', 'A Rose Is Still a Rose (song)', 'A Taste of Honey (band)', 'A cappella', 'Academic grading in the United States', 'Academy of Achievement', 'Adele', 'Adult contemporary', 'African-American music', 'African diaspora', 'Agence France-Press', 'Alanis Morissette', 'Alec Foege', 'Alicia Keys', 'Alison Krauss', 'AllMusic', 'All Falls Down', 'All That I Can Say', 'Alto', 'Amazon.com', 'America (band)', 'Amy Winehouse', 'Arcade Fire', 'Aretha Franklin', 'Arrested Development (group)', 'Artistdirect', 'As the World Turns', 'Associated Press', 'BBC News', 'BET Awards 2005', 'Babel (album)', 'Back on the Block', 'Ballantine Books', 'Baptist', 'Bar Mitzvah', 'Barbra Streisand', 'Beck', 'Bedford-Stuyvesant', 'Bee Gees', 'Beloved (1998 film)',
# ...
